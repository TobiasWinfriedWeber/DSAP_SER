# %% [markdown]
# <a href="https://colab.research.google.com/github/TobiasWinfriedWeber/DSAP_SER/blob/main/mfcc_ANN_zeropadded_ang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import basic libraries
import matplotlib.pyplot as plt
import numpy as np
# Mount to drive
from google.colab import drive
drive.flush_and_unmount()
drive.mount("/content/drive")
# Import torch
import torch
import torch.nn as nn
import torch.optim as optim
import os
from scipy.io import wavfile
import shutil
import csv
path = "/content/drive" # /content is pretty much the root. you can choose other path in your colab workspace
os.chdir(path)
# Out:
# Drive not mounted, so nothing to flush and unmount.
# Mounted at /content/drive

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("We are using the following device for learning:",device)
# Out:
# We are using the following device for learning: cpu

# %%
import torch.nn as nn
import torch.optim as optim
import torch
import torchaudio
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import Compose
import os
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import math
import os
import torchaudio
from torchaudio.transforms import MFCC
from torch.utils.data import Dataset
from torch.nn.utils.rnn import pad_sequence
import librosa
import numpy as np
class SimpleFCNN(nn.Module):
    def __init__(self, input_size, hidden_neurons):
        super(SimpleFCNN, self).__init__()

        # Fully connected (linear) layer
        self.fc1 = nn.Linear(input_size, hidden_neurons)
        # ReLU activation function for hidden layer
        self.relu = nn.ReLU()
        # Output layer
        self.output_layer = nn.Linear(hidden_neurons, 2)  # Two output classes

    def forward(self, x):
        # Flatten for fully connected layer
        x = x.view(x.size(0), -1)
        # Fully connected layer
        x = self.fc1(x)
        x = self.relu(x)
        # Output layer
        x = self.output_layer(x)
        x = nn.functional.softmax(x, dim=1)  # Apply softmax activation

        return x

# %%
# Install required packages
import torch
import torchaudio
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import Compose
import os
import pandas as pd
from sklearn.model_selection import train_test_split

# Load your CSV file
#csv_path = "/content/drive/My Drive/DSAP/BigProject/DATA/ANGRY_CLASSIFICATION/labels.csv"
csv_path = "/content/drive/My Drive/DSAP/BigProject/DATA/ANGRY_CLASSIFICATION/labels_sameprobability.csv"
df = pd.read_csv(csv_path)

# Split the data into training, validation, and test sets
# Shuffle the dataframe
df = df.sample(frac=1, random_state=42)
#df = df.head(4000)
temp_df, test_df = train_test_split(df, test_size=0.2, random_state=42)
train_df, val_df = train_test_split(temp_df, test_size=0.2, random_state=42)



class AudioDataset(Dataset):
    def __init__(self, dataframe, root_dir, transform=None):
        self.dataframe = dataframe
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        file_name = os.path.join(self.root_dir, self.dataframe.iloc[idx, 0])
        waveform, sample_rate = librosa.load(file_name)
        label = torch.tensor(self.dataframe.iloc[idx, 1], dtype=torch.float32)  # Assuming labels are in the second column

        # Normalize the waveform to be between 0 and 1
        #

        # Extract MFCC features
        mfcc = librosa.feature.mfcc(y=waveform, sr=sample_rate, n_mfcc=13, win_length = 400, n_fft=512, hop_length=30)
        mfcc = 2 * (mfcc - mfcc.min()) / (mfcc.max() - mfcc.min()) - 1
        #mfcc = (mfcc - mfcc.min()) / (mfcc.max() - mfcc.min())

        # Convert to PyTorch tensor
        mfcc_tensor = torch.tensor(mfcc, dtype=torch.float32)

        return mfcc_tensor, label


# Set the path to your directory containing audio files
#audio_dir = "/content/drive/My Drive/DSAP/BigProject/DATA/CremaD/AudioWAV_samelength"
audio_dir = "/content/drive/My Drive/DSAP/BigProject/DATA/CremaD/ANG_SAMEPROBABILITY"
# Create instances of the custom dataset for training, validation, and test
train_dataset = AudioDataset(dataframe=train_df, root_dir=audio_dir)
val_dataset = AudioDataset(dataframe=val_df, root_dir=audio_dir)
test_dataset = AudioDataset(dataframe=test_df, root_dir=audio_dir)

# Define data loaders
#train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
## Settings
sampling_rate = 16e3 #was tested before
#Calculate the number of samples per window for a 25ms window size
kernelCON_len = int(0.025 * sampling_rate)
# move window of one fourth of kernel size
shiftCON_size = int(0.25 * kernelCON_len)
print(f"Kernel size is : {kernelCON_len} Samples")

hidden_neurons = 64
num_epochs = 10000
# Out:
# Kernel size is : 400 Samples

# %%
# Create an instance of the model, define loss
model = SimpleFCNN(input_size = 47788, hidden_neurons=hidden_neurons)
#model = CNN(in_size=5513, hidden_neurons=hidden_neurons, filter_len=3, filter_shift = 3, maxPoolSize=maxPoolLen, maxPoolShift=maxPoolStride)
#optimizer = optim.Adam(model.parameters(), lr=0.9)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9) # in paper: sgd 0.9, 0.9
lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=15, gamma=0.2) # gamma = 0.2
model.to( device )
criterion = nn.CrossEntropyLoss()
#criterion = nn.MSELoss()

# Early stopping parameters
patience = 50  # Number of epochs with no improvement after which training will be stopped
best_val_loss = float('inf')
counter_no_improve = 0

# Save parameters
trainingloss_per_epoch = []
validationloss_per_epoch = []
accuracy_per_epoch = []

# %%
# Training loop
#max_grad_norm = 100000000.0
dynamic_batch_size = 598
from torch.nn.utils import clip_grad_norm_
import torch
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
import os


for epoch in range(num_epochs):
    model.train()
    i=0

      # Set your initial batch size
    train_loader_epoch = DataLoader(train_dataset, batch_size=dynamic_batch_size, shuffle=True)
    lenTrainLoader = len(train_loader_epoch)
    for batch in train_loader_epoch:
        input_save, label_save = batch
        if not torch.isnan(input_save.unsqueeze(1)).any():
          inputs, labels = batch
          inputs, labels = inputs.to(device), labels.to(device)

          # Zero the gradients
          optimizer.zero_grad()

          # Forward pass
          outputs = model(inputs)
          #outputs = torch.sigmoid(outputs)
          #if i%1 == 0 or i==0:
            #print(labels.unsqueeze(1))
            #print("#######################################################")
          #print(outputs)
          #print(labels.long())
            #print(labels)
            #print("#######################################################")
          print("Number batch " + str(i+1) + " of " + str(lenTrainLoader))
          #if math.isnan(outputs):
          #  print(input_save)
          # Calculate the loss
          loss = criterion(outputs, labels.long())



          # Backward pass
          loss.backward()
          #clip_grad_norm_(model.parameters(), max_grad_norm)

          # Update weights
          optimizer.step()

          i += 1

    # Validation loop
    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for batch in val_loader:
            inputs, labels = batch
            inputs, labels = inputs.to(device), labels.to(device)

            # Forward pass
            outputs = model(inputs)
            #outputs = torch.sigmoid(outputs)

            # Calculate the loss
            #loss = criterion(outputs, labels.long())
            loss = criterion(outputs, labels.long())
            val_loss += loss.item()

            # Accuracy calculation
            predicted = torch.argmax(outputs, dim=1)
            #predicted = torch.round(outputs)
            total += labels.size(0)
            correct += (predicted == labels.unsqueeze(1)).sum().item()

    average_val_loss = val_loss / len(val_loader)
    accuracy = correct / total
    lr_scheduler.step()
    print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}, Validation Loss: {average_val_loss:.4f}, Accuracy: {accuracy * 100:.2f}%')
    # Append values to the existing lists
    trainingloss_per_epoch.append(loss.cpu().item())
    validationloss_per_epoch.append(average_val_loss)
    accuracy_per_epoch.append(accuracy)
    np.savetxt('/content/drive/My Drive/mfcc_ANN_73ACC/training_loss.csv', trainingloss_per_epoch, delimiter=',')
    np.savetxt('/content/drive/My Drive/mfcc_ANN_73ACC/validation_loss.csv', validationloss_per_epoch, delimiter=',')
    np.savetxt('/content/drive/My Drive/mfcc_ANN_73ACC/accuracy.csv', accuracy_per_epoch, delimiter=',')
    # Learning rate scheduling
    lr_scheduler.step()


    # Early stopping
    if average_val_loss < best_val_loss:
        torch.save(model.state_dict(), '/content/drive/My Drive/mfcc_ANN_73ACC/CNN_PAPER.pth')

        #if dynamic_batch_size*1.5<598:
        #  dynamic_batch_size = int(dynamic_batch_size*1.5)
        best_val_loss = average_val_loss
        counter_no_improve = 0
    else:
        counter_no_improve += 1

    #if counter_no_improve >= patience:
    #    print(f'Early stopping! No improvement for {patience} consecutive epochs.')
    #    break
print('Training finished.')
# Out:
# Number batch 1 of 1
# Epoch [1/10000], Loss: 0.7488, Validation Loss: 0.6970, Accuracy: 46.00%
# Number batch 1 of 1
# Epoch [2/10000], Loss: 0.7120, Validation Loss: 0.6921, Accuracy: 47.33%
# Number batch 1 of 1
# Epoch [3/10000], Loss: 0.7433, Validation Loss: 0.6928, Accuracy: 46.00%
# Number batch 1 of 1
# Epoch [4/10000], Loss: 0.7320, Validation Loss: 0.6890, Accuracy: 47.33%
# Number batch 1 of 1
# Epoch [5/10000], Loss: 0.7222, Validation Loss: 0.6851, Accuracy: 56.67%
# Number batch 1 of 1
# Epoch [6/10000], Loss: 0.7436, Validation Loss: 0.6836, Accuracy: 52.00%
# Number batch 1 of 1
# Epoch [7/10000], Loss: 0.7223, Validation Loss: 0.6778, Accuracy: 66.00%
# Number batch 1 of 1
# Epoch [8/10000], Loss: 0.7523, Validation Loss: 0.6766, Accuracy: 58.67%
# Number batch 1 of 1
# Epoch [9/10000], Loss: 0.7456, Validation Loss: 0.6750, Accuracy: 63.33%
# Number batch 1 of 1
# Epoch [10/10000], Loss: 0.7333, Validation Loss: 0.6730, Accuracy: 66.00%
# Number batch 1 of 1
# Epoch [11/10000], Loss: 0.7266, Validation Loss: 0.6714, Accuracy: 65.33%
# Number batch 1 of 1
# Epoch [12/10000], Loss: 0.7305, Validation Loss: 0.6708, Accuracy: 65.33%
# Number batch 1 of 1
# Epoch [13/10000], Loss: 0.7414, Validation Loss: 0.6708, Accuracy: 65.33%
# Number batch 1 of 1
# Epoch [14/10000], Loss: 0.7502, Validation Loss: 0.6706, Accuracy: 65.33%
# Number batch 1 of 1
# Epoch [15/10000], Loss: 0.7505, Validation Loss: 0.6696, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [16/10000], Loss: 0.7491, Validation Loss: 0.6692, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [17/10000], Loss: 0.7465, Validation Loss: 0.6687, Accuracy: 65.33%
# Number batch 1 of 1
# Epoch [18/10000], Loss: 0.7433, Validation Loss: 0.6682, Accuracy: 65.33%
# Number batch 1 of 1
# Epoch [19/10000], Loss: 0.7402, Validation Loss: 0.6676, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [20/10000], Loss: 0.7377, Validation Loss: 0.6672, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [21/10000], Loss: 0.7362, Validation Loss: 0.6668, Accuracy: 65.33%
# Number batch 1 of 1
# Epoch [22/10000], Loss: 0.7358, Validation Loss: 0.6665, Accuracy: 65.33%
# Number batch 1 of 1
# Epoch [23/10000], Loss: 0.7366, Validation Loss: 0.6663, Accuracy: 65.33%
# Number batch 1 of 1
# Epoch [24/10000], Loss: 0.7369, Validation Loss: 0.6663, Accuracy: 66.00%
# Number batch 1 of 1
# Epoch [25/10000], Loss: 0.7374, Validation Loss: 0.6663, Accuracy: 65.33%
# Number batch 1 of 1
# Epoch [26/10000], Loss: 0.7380, Validation Loss: 0.6663, Accuracy: 65.33%
# Number batch 1 of 1
# Epoch [27/10000], Loss: 0.7387, Validation Loss: 0.6663, Accuracy: 65.33%
# Number batch 1 of 1
# Epoch [28/10000], Loss: 0.7395, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [29/10000], Loss: 0.7403, Validation Loss: 0.6664, Accuracy: 64.00%
# Number batch 1 of 1
# Epoch [30/10000], Loss: 0.7411, Validation Loss: 0.6664, Accuracy: 64.00%
# Number batch 1 of 1
# Epoch [31/10000], Loss: 0.7413, Validation Loss: 0.6664, Accuracy: 64.00%
# Number batch 1 of 1
# Epoch [32/10000], Loss: 0.7414, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [33/10000], Loss: 0.7415, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [34/10000], Loss: 0.7417, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [35/10000], Loss: 0.7418, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [36/10000], Loss: 0.7419, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [37/10000], Loss: 0.7421, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [38/10000], Loss: 0.7422, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [39/10000], Loss: 0.7422, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [40/10000], Loss: 0.7422, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [41/10000], Loss: 0.7422, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [42/10000], Loss: 0.7422, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [43/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [44/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [45/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [46/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [47/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [48/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [49/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [50/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [51/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [52/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [53/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [54/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [55/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [56/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [57/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [58/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [59/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [60/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [61/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [62/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [63/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [64/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [65/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [66/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [67/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [68/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [69/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [70/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [71/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [72/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [73/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [74/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [75/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [76/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [77/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [78/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [79/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [80/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [81/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [82/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [83/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [84/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [85/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [86/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [87/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [88/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [89/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [90/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [91/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [92/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [93/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [94/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [95/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [96/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [97/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [98/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [99/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [100/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [101/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [102/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [103/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [104/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [105/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [106/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [107/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [108/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [109/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [110/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [111/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [112/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [113/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [114/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [115/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [116/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [117/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [118/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [119/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [120/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [121/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [122/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [123/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [124/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [125/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [126/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [127/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [128/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [129/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [130/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [131/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [132/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [133/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [134/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [135/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [136/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [137/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [138/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [139/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [140/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [141/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [142/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [143/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [144/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [145/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [146/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [147/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [148/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [149/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [150/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [151/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [152/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [153/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [154/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [155/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [156/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [157/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [158/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [159/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [160/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [161/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [162/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [163/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [164/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [165/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [166/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [167/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [168/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# Epoch [169/10000], Loss: 0.7423, Validation Loss: 0.6664, Accuracy: 64.67%
# Number batch 1 of 1
# <ipython-input-6-c9bd001fb457>:35: UserWarning: PySoundFile failed. Trying audioread instead.
#   waveform, sample_rate = librosa.load(file_name)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/librosa/core/audio.py", line 175, in load
#     y, sr_native = __soundfile_load(path, offset, duration, dtype)
#   File "/usr/local/lib/python3.10/dist-packages/librosa/core/audio.py", line 208, in __soundfile_load
#     context = sf.SoundFile(path)
#   File "/usr/local/lib/python3.10/dist-packages/soundfile.py", line 658, in __init__
#     self._file = self._open(file, mode_int, closefd)
#   File "/usr/local/lib/python3.10/dist-packages/soundfile.py", line 1216, in _open
#     raise LibsndfileError(err, prefix="Error opening {0!r}: ".format(self.name))
# soundfile.LibsndfileError: Error opening '/content/drive/My Drive/DSAP/BigProject/DATA/CremaD/ANG_SAMEPROBABILITY/1027_IEO_FEA_LO.wav': System error.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-14-a658e73d7ff6>", line 61, in <cell line: 11>
#     for batch in val_loader:
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 630, in __next__
#     data = self._next_data()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 674, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py", line 51, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py", line 51, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "<ipython-input-6-c9bd001fb457>", line 35, in __getitem__
#     waveform, sample_rate = librosa.load(file_name)
#   File "/usr/local/lib/python3.10/dist-packages/librosa/core/audio.py", line 183, in load
#     y, sr_native = __audioread_load(path, offset, duration, dtype)
#   File "<decorator-gen-119>", line 2, in __audioread_load
#   File "/usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py", line 59, in __wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/librosa/core/audio.py", line 239, in __audioread_load
#     reader = audioread.audio_open(path)
#   File "/usr/local/lib/python3.10/dist-packages/audioread/__init__.py", line 127, in audio_open
#     return BackendClass(path)
#   File "/usr/local/lib/python3.10/dist-packages/audioread/rawread.py", line 59, in __init__
#     self._fh = open(filename, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/DSAP/BigProject/DATA/CremaD/ANG_SAMEPROBABILITY/1027_IEO_FEA_LO.wav'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'FileNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/librosa/core/audio.py", line 175, in load
#     y, sr_native = __soundfile_load(path, offset, duration, dtype)
#   File "/usr/local/lib/python3.10/dist-packages/librosa/core/audio.py", line 208, in __soundfile_load
#     context = sf.SoundFile(path)
#   File "/usr/local/lib/python3.10/dist-packages/soundfile.py", line 658, in __init__
#     self._file = self._open(file, mode_int, closefd)
#   File "/usr/local/lib/python3.10/dist-packages/soundfile.py", line 1216, in _open
#     raise LibsndfileError(err, prefix="Error opening {0!r}: ".format(self.name))
# soundfile.LibsndfileError: Error opening '/content/drive/My Drive/DSAP/BigProject/DATA/CremaD/ANG_SAMEPROBABILITY/1027_IEO_FEA_LO.wav': System error.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-14-a658e73d7ff6>", line 61, in <cell line: 11>
#     for batch in val_loader:
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 630, in __next__
#     data = self._next_data()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 674, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py", line 51, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py", line 51, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "<ipython-input-6-c9bd001fb457>", line 35, in __getitem__
#     waveform, sample_rate = librosa.load(file_name)
#   File "/usr/local/lib/python3.10/dist-packages/librosa/core/audio.py", line 183, in load
#     y, sr_native = __audioread_load(path, offset, duration, dtype)
#   File "<decorator-gen-119>", line 2, in __audioread_load
#   File "/usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py", line 59, in __wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/librosa/core/audio.py", line 239, in __audioread_load
#     reader = audioread.audio_open(path)
#   File "/usr/local/lib/python3.10/dist-packages/audioread/__init__.py", line 127, in audio_open
#     return BackendClass(path)
#   File "/usr/local/lib/python3.10/dist-packages/audioread/rawread.py", line 59, in __init__
#     self._fh = open(filename, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/DSAP/BigProject/DATA/CremaD/ANG_SAMEPROBABILITY/1027_IEO_FEA_LO.wav'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'FileNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/librosa/core/audio.py", line 175, in load
#     y, sr_native = __soundfile_load(path, offset, duration, dtype)
#   File "/usr/local/lib/python3.10/dist-packages/librosa/core/audio.py", line 208, in __soundfile_load
#     context = sf.SoundFile(path)
#   File "/usr/local/lib/python3.10/dist-packages/soundfile.py", line 658, in __init__
#     self._file = self._open(file, mode_int, closefd)
#   File "/usr/local/lib/python3.10/dist-packages/soundfile.py", line 1216, in _open
#     raise LibsndfileError(err, prefix="Error opening {0!r}: ".format(self.name))
# soundfile.LibsndfileError: Error opening '/content/drive/My Drive/DSAP/BigProject/DATA/CremaD/ANG_SAMEPROBABILITY/1027_IEO_FEA_LO.wav': System error.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-14-a658e73d7ff6>", line 61, in <cell line: 11>
#     for batch in val_loader:
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 630, in __next__
#     data = self._next_data()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 674, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py", line 51, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py", line 51, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "<ipython-input-6-c9bd001fb457>", line 35, in __getitem__
#     waveform, sample_rate = librosa.load(file_name)
#   File "/usr/local/lib/python3.10/dist-packages/librosa/core/audio.py", line 183, in load
#     y, sr_native = __audioread_load(path, offset, duration, dtype)
#   File "<decorator-gen-119>", line 2, in __audioread_load
#   File "/usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py", line 59, in __wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/librosa/core/audio.py", line 239, in __audioread_load
#     reader = audioread.audio_open(path)
#   File "/usr/local/lib/python3.10/dist-packages/audioread/__init__.py", line 127, in audio_open
#     return BackendClass(path)
#   File "/usr/local/lib/python3.10/dist-packages/audioread/rawread.py", line 59, in __init__
#     self._fh = open(filename, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/DSAP/BigProject/DATA/CremaD/ANG_SAMEPROBABILITY/1027_IEO_FEA_LO.wav'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'FileNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %%
model.load_state_dict(torch.load('/content/drive/My Drive/mfcc_ANN_73ACC/CNN_PAPER.pth', map_location=torch.device('cpu')))
model.eval()  # Set the model to evaluation mode

test_loss = 0.0
correct = 0
total = 0
angry_detected = 0

with torch.no_grad():
    i = 0
    len_test = len(test_loader)
    for batch in test_loader:  # Assuming you have a DataLoader for your test set
        inputs, labels = batch
        inputs, labels = inputs.to(device), labels.to(device)
        if i % 100 == 0:
            print(str(i) + " / " + str(len_test))
        i += 1

        # Forward pass
        probs = model(inputs)
        loss = criterion(probs, labels.long())  # Use .long() for integer labels in CrossEntropyLoss
        test_loss += loss.item()

        # Accuracy calculation
        predicted = torch.argmax(probs, dim=1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        # Angry detection calculation
        angry_detected += ((predicted == 1) & (labels == 1)).sum().item()

average_test_loss = test_loss / len(test_loader)
accuracy = correct / total
angry_det_percentage = angry_detected / total

print(f'Test Loss: {average_test_loss:.4f}, Test Accuracy: {accuracy}, Angry Detection Percentage: {angry_det_percentage}')
# Out:
# 0 / 188
# 100 / 188
# Test Loss: 0.6557, Test Accuracy: 0.7340425531914894, Angry Detection Percentage: 0.30851063829787234

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the data from the CSV file
accuracy_per_epoch = np.loadtxt('/content/drive/My Drive/mfcc_ANN_73ACC/accuracy.csv', delimiter=',')
# Load the data from the CSV files
validation_loss_per_epoch = np.loadtxt('/content/drive/My Drive/mfcc_ANN_73ACC/validation_loss.csv', delimiter=',')
trainingloss_per_epoch = np.loadtxt('/content/drive/My Drive/mfcc_ANN_73ACC/training_loss.csv', delimiter=',')

# Plot for Validation Loss
plt.figure(figsize=(8, 4))
plt.plot(validation_loss_per_epoch, label='Validation Loss', color='red', linestyle='--')
plt.xlabel('Epoch')
plt.ylabel('Validation Loss')
plt.title('Validation Loss per Epoch')
plt.legend()
plt.show()

# %%
# Plot for Accuracy
plt.figure(figsize=(8, 4))
plt.plot(accuracy_per_epoch, label='Accuracy', color='blue', linestyle='-')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy per Epoch')
plt.legend()
plt.show()

# %%
# Plot the data using the index as the x-axis values
plt.plot(trainingloss_per_epoch)
plt.xlabel('Epoch')
plt.ylabel('Trainingsloss')
plt.title('Trainingsloss per Epoch')
plt.show()
