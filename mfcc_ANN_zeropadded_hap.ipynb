# %% [markdown]
# <a href="https://colab.research.google.com/github/TobiasWinfriedWeber/DSAP_SER/blob/main/mfcc_ANN_zeropadded_hap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import basic libraries
import matplotlib.pyplot as plt
import numpy as np
# Mount to drive
from google.colab import drive
drive.flush_and_unmount()
drive.mount("/content/drive")
# Import torch
import torch
import torch.nn as nn
import torch.optim as optim
import os
from scipy.io import wavfile
import shutil
import csv
path = "/content/drive" # /content is pretty much the root. you can choose other path in your colab workspace
os.chdir(path)
# Out:
# Drive not mounted, so nothing to flush and unmount.
# Mounted at /content/drive

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("We are using the following device for learning:",device)
# Out:
# We are using the following device for learning: cpu

# %%
import torch.nn as nn
import torch.optim as optim
import torch
import torchaudio
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import Compose
import os
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import math
import os
import torchaudio
from torchaudio.transforms import MFCC
from torch.utils.data import Dataset
from torch.nn.utils.rnn import pad_sequence
import librosa
import numpy as np
class SimpleFCNN(nn.Module):
    def __init__(self, input_size, hidden_neurons):
        super(SimpleFCNN, self).__init__()

        # Fully connected (linear) layer
        self.fc1 = nn.Linear(input_size, hidden_neurons)
        # ReLU activation function for hidden layer
        self.relu = nn.ReLU()
        # Output layer
        self.output_layer = nn.Linear(hidden_neurons, 2)  # Two output classes

    def forward(self, x):
        # Flatten for fully connected layer
        x = x.view(x.size(0), -1)
        # Fully connected layer
        x = self.fc1(x)
        x = self.relu(x)
        # Output layer
        x = self.output_layer(x)
        x = nn.functional.softmax(x, dim=1)  # Apply softmax activation

        return x

# %%
# Install required packages
import torch
import torchaudio
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import Compose
import os
import pandas as pd
from sklearn.model_selection import train_test_split

# Load your CSV file
#csv_path = "/content/drive/My Drive/DSAP/BigProject/DATA/ANGRY_CLASSIFICATION/labels.csv"
csv_path = "/content/drive/My Drive/DSAP/BigProject/DATA/HAPPY_CLASSIFICATION/labels_sameprobability.csv"
df = pd.read_csv(csv_path)

# Split the data into training, validation, and test sets
# Shuffle the dataframe
df = df.sample(frac=1, random_state=42)
#df = df.head(4000)
temp_df, test_df = train_test_split(df, test_size=0.2, random_state=42)
train_df, val_df = train_test_split(temp_df, test_size=0.2, random_state=42)



class AudioDataset(Dataset):
    def __init__(self, dataframe, root_dir, transform=None):
        self.dataframe = dataframe
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        file_name = os.path.join(self.root_dir, self.dataframe.iloc[idx, 0])
        waveform, sample_rate = librosa.load(file_name)
        label = torch.tensor(self.dataframe.iloc[idx, 1], dtype=torch.float32)  # Assuming labels are in the second column

        # Normalize the waveform to be between 0 and 1
        #

        # Extract MFCC features
        mfcc = librosa.feature.mfcc(y=waveform, sr=sample_rate, n_mfcc=13, win_length = 400, n_fft=512, hop_length=30)
        mfcc = 2 * (mfcc - mfcc.min()) / (mfcc.max() - mfcc.min()) - 1
        #mfcc = (mfcc - mfcc.min()) / (mfcc.max() - mfcc.min())

        # Convert to PyTorch tensor
        mfcc_tensor = torch.tensor(mfcc, dtype=torch.float32)

        return mfcc_tensor, label


# Set the path to your directory containing audio files
#audio_dir = "/content/drive/My Drive/DSAP/BigProject/DATA/CremaD/AudioWAV_samelength"
audio_dir = "/content/drive/My Drive/DSAP/BigProject/DATA/CremaD/HAP_SAMEPROBABILITY"
# Create instances of the custom dataset for training, validation, and test
train_dataset = AudioDataset(dataframe=train_df, root_dir=audio_dir)
val_dataset = AudioDataset(dataframe=val_df, root_dir=audio_dir)
test_dataset = AudioDataset(dataframe=test_df, root_dir=audio_dir)

# Define data loaders
#train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
## Settings
sampling_rate = 16e3 #was tested before
#Calculate the number of samples per window for a 25ms window size
kernelCON_len = int(0.025 * sampling_rate)
# move window of one fourth of kernel size
shiftCON_size = int(0.25 * kernelCON_len)
print(f"Kernel size is : {kernelCON_len} Samples")

hidden_neurons = 64
num_epochs = 10000
# Out:
# Kernel size is : 400 Samples

# %%
# Create an instance of the model, define loss
model = SimpleFCNN(input_size = 47788, hidden_neurons=hidden_neurons)
#model = CNN(in_size=5513, hidden_neurons=hidden_neurons, filter_len=3, filter_shift = 3, maxPoolSize=maxPoolLen, maxPoolShift=maxPoolStride)
#optimizer = optim.Adam(model.parameters(), lr=0.9)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9) # in paper: sgd 0.9, 0.9
lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=15, gamma=0.2) # gamma = 0.2
model.to( device )
criterion = nn.CrossEntropyLoss()
#criterion = nn.MSELoss()

# Early stopping parameters
patience = 50  # Number of epochs with no improvement after which training will be stopped
best_val_loss = float('inf')
counter_no_improve = 0

# Save parameters
trainingloss_per_epoch = []
validationloss_per_epoch = []
accuracy_per_epoch = []

# %%
# Training loop
#max_grad_norm = 100000000.0
dynamic_batch_size = 902
from torch.nn.utils import clip_grad_norm_
import torch
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
import os


for epoch in range(num_epochs):
    model.train()
    i=0

      # Set your initial batch size
    train_loader_epoch = DataLoader(train_dataset, batch_size=dynamic_batch_size, shuffle=True)
    lenTrainLoader = len(train_loader_epoch)
    for batch in train_loader_epoch:
        input_save, label_save = batch
        if not torch.isnan(input_save.unsqueeze(1)).any():
          inputs, labels = batch
          inputs, labels = inputs.to(device), labels.to(device)

          # Zero the gradients
          optimizer.zero_grad()

          # Forward pass
          outputs = model(inputs)
          #outputs = torch.sigmoid(outputs)
          #if i%1 == 0 or i==0:
            #print(labels.unsqueeze(1))
            #print("#######################################################")
          #print(outputs)
          #print(labels.long())
            #print(labels)
            #print("#######################################################")
          print("Number batch " + str(i+1) + " of " + str(lenTrainLoader))
          #if math.isnan(outputs):
          #  print(input_save)
          # Calculate the loss
          loss = criterion(outputs, labels.long())



          # Backward pass
          loss.backward()
          #clip_grad_norm_(model.parameters(), max_grad_norm)

          # Update weights
          optimizer.step()

          i += 1

    # Validation loop
    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for batch in val_loader:
            inputs, labels = batch
            inputs, labels = inputs.to(device), labels.to(device)

            # Forward pass
            outputs = model(inputs)
            #outputs = torch.sigmoid(outputs)

            # Calculate the loss
            #loss = criterion(outputs, labels.long())
            loss = criterion(outputs, labels.long())
            val_loss += loss.item()

            # Accuracy calculation
            predicted = torch.argmax(outputs, dim=1)
            #predicted = torch.round(outputs)
            total += labels.size(0)
            correct += (predicted == labels.unsqueeze(1)).sum().item()

    average_val_loss = val_loss / len(val_loader)
    accuracy = correct / total
    lr_scheduler.step()
    print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}, Validation Loss: {average_val_loss:.4f}, Accuracy: {accuracy * 100:.2f}%')
    # Append values to the existing lists
    trainingloss_per_epoch.append(loss.cpu().item())
    validationloss_per_epoch.append(average_val_loss)
    accuracy_per_epoch.append(accuracy)
    np.savetxt('/content/drive/My Drive/mfcc_ANN_highAcc_hap/training_loss.csv', trainingloss_per_epoch, delimiter=',')
    np.savetxt('/content/drive/My Drive/mfcc_ANN_highAcc_hap/validation_loss.csv', validationloss_per_epoch, delimiter=',')
    np.savetxt('/content/drive/My Drive/mfcc_ANN_highAcc_hap/accuracy.csv', accuracy_per_epoch, delimiter=',')
    # Learning rate scheduling
    lr_scheduler.step()


    # Early stopping
    if average_val_loss < best_val_loss:
        torch.save(model.state_dict(), '/content/drive/My Drive/mfcc_ANN_highAcc_hap/CNN_PAPER.pth')

        #if dynamic_batch_size*1.5<598:
        #  dynamic_batch_size = int(dynamic_batch_size*1.5)
        best_val_loss = average_val_loss
        counter_no_improve = 0
    else:
        counter_no_improve += 1

    #if counter_no_improve >= patience:
    #    print(f'Early stopping! No improvement for {patience} consecutive epochs.')
    #    break
print('Training finished.')
# Out:
# Number batch 1 of 1
# Epoch [1/10000], Loss: 0.9620, Validation Loss: 0.7384, Accuracy: 46.02%
# Number batch 1 of 1
# Epoch [2/10000], Loss: 0.7737, Validation Loss: 0.6989, Accuracy: 46.02%
# Number batch 1 of 1
# Epoch [3/10000], Loss: 0.5827, Validation Loss: 0.6889, Accuracy: 53.98%
# Number batch 1 of 1
# Epoch [4/10000], Loss: 0.9855, Validation Loss: 0.7372, Accuracy: 46.02%
# Number batch 1 of 1
# Epoch [5/10000], Loss: 0.8502, Validation Loss: 0.7041, Accuracy: 46.02%
# Number batch 1 of 1
# Epoch [6/10000], Loss: 0.5820, Validation Loss: 0.6840, Accuracy: 53.98%
# Number batch 1 of 1
# Epoch [7/10000], Loss: 0.9839, Validation Loss: 0.7255, Accuracy: 46.02%
# Number batch 1 of 1
# Epoch [8/10000], Loss: 0.8414, Validation Loss: 0.6907, Accuracy: 47.35%
# Number batch 1 of 1
# Epoch [9/10000], Loss: 0.7788, Validation Loss: 0.6818, Accuracy: 58.41%
# Number batch 1 of 1
# Epoch [10/10000], Loss: 0.7314, Validation Loss: 0.6773, Accuracy: 60.18%
# Number batch 1 of 1
# Epoch [11/10000], Loss: 0.7344, Validation Loss: 0.6768, Accuracy: 61.06%
# Number batch 1 of 1
# Epoch [12/10000], Loss: 0.7801, Validation Loss: 0.6796, Accuracy: 60.62%
# Number batch 1 of 1
# Epoch [13/10000], Loss: 0.8321, Validation Loss: 0.6848, Accuracy: 56.19%
# Number batch 1 of 1
# Epoch [14/10000], Loss: 0.8541, Validation Loss: 0.6871, Accuracy: 51.33%
# Number batch 1 of 1
# Epoch [15/10000], Loss: 0.8359, Validation Loss: 0.6836, Accuracy: 58.41%
# Number batch 1 of 1
# Epoch [16/10000], Loss: 0.8277, Validation Loss: 0.6823, Accuracy: 58.41%
# Number batch 1 of 1
# Epoch [17/10000], Loss: 0.8166, Validation Loss: 0.6807, Accuracy: 58.85%
# Number batch 1 of 1
# Epoch [18/10000], Loss: 0.8044, Validation Loss: 0.6792, Accuracy: 59.29%
# Number batch 1 of 1
# Epoch [19/10000], Loss: 0.7931, Validation Loss: 0.6779, Accuracy: 60.18%
# Number batch 1 of 1
# Epoch [20/10000], Loss: 0.7844, Validation Loss: 0.6769, Accuracy: 61.06%
# Number batch 1 of 1
# Epoch [21/10000], Loss: 0.7794, Validation Loss: 0.6763, Accuracy: 61.95%
# Number batch 1 of 1
# Epoch [22/10000], Loss: 0.7787, Validation Loss: 0.6761, Accuracy: 62.39%
# Number batch 1 of 1
# Epoch [23/10000], Loss: 0.7819, Validation Loss: 0.6762, Accuracy: 61.95%
# Number batch 1 of 1
# Epoch [24/10000], Loss: 0.7832, Validation Loss: 0.6763, Accuracy: 61.50%
# Number batch 1 of 1
# Epoch [25/10000], Loss: 0.7850, Validation Loss: 0.6764, Accuracy: 61.06%
# Number batch 1 of 1
# Epoch [26/10000], Loss: 0.7873, Validation Loss: 0.6766, Accuracy: 61.06%
# Number batch 1 of 1
# Epoch [27/10000], Loss: 0.7898, Validation Loss: 0.6768, Accuracy: 60.18%
# Number batch 1 of 1
# Epoch [28/10000], Loss: 0.7926, Validation Loss: 0.6770, Accuracy: 60.18%
# Number batch 1 of 1
# Epoch [29/10000], Loss: 0.7954, Validation Loss: 0.6772, Accuracy: 60.18%
# Number batch 1 of 1
# Epoch [30/10000], Loss: 0.7983, Validation Loss: 0.6775, Accuracy: 60.18%
# Number batch 1 of 1
# Epoch [31/10000], Loss: 0.7989, Validation Loss: 0.6775, Accuracy: 60.18%
# Number batch 1 of 1
# Epoch [32/10000], Loss: 0.7994, Validation Loss: 0.6775, Accuracy: 60.18%
# Number batch 1 of 1
# Epoch [33/10000], Loss: 0.7999, Validation Loss: 0.6776, Accuracy: 60.62%
# Number batch 1 of 1
# Epoch [34/10000], Loss: 0.8004, Validation Loss: 0.6776, Accuracy: 60.62%
# Number batch 1 of 1
# Epoch [35/10000], Loss: 0.8009, Validation Loss: 0.6777, Accuracy: 60.62%
# Number batch 1 of 1
# Epoch [36/10000], Loss: 0.8014, Validation Loss: 0.6777, Accuracy: 60.18%
# Number batch 1 of 1
# Epoch [37/10000], Loss: 0.8018, Validation Loss: 0.6777, Accuracy: 60.18%
# Number batch 1 of 1
# Epoch [38/10000], Loss: 0.8022, Validation Loss: 0.6778, Accuracy: 60.18%
# Number batch 1 of 1
# Epoch [39/10000], Loss: 0.8023, Validation Loss: 0.6778, Accuracy: 60.18%
# Number batch 1 of 1
# Epoch [40/10000], Loss: 0.8024, Validation Loss: 0.6778, Accuracy: 60.18%
# Number batch 1 of 1
# Epoch [41/10000], Loss: 0.8024, Validation Loss: 0.6778, Accuracy: 60.18%
# Number batch 1 of 1
# Epoch [42/10000], Loss: 0.8025, Validation Loss: 0.6778, Accuracy: 60.18%
# Number batch 1 of 1
# Epoch [43/10000], Loss: 0.8026, Validation Loss: 0.6778, Accuracy: 60.18%
# Number batch 1 of 1
# Epoch [44/10000], Loss: 0.8026, Validation Loss: 0.6778, Accuracy: 60.18%
# Number batch 1 of 1
# Epoch [45/10000], Loss: 0.8027, Validation Loss: 0.6778, Accuracy: 60.18%
# Number batch 1 of 1
# Epoch [46/10000], Loss: 0.8027, Validation Loss: 0.6778, Accuracy: 60.18%
# Number batch 1 of 1
# Epoch [47/10000], Loss: 0.8027, Validation Loss: 0.6778, Accuracy: 60.18%
# Number batch 1 of 1
# Epoch [48/10000], Loss: 0.8027, Validation Loss: 0.6778, Accuracy: 60.18%
# Number batch 1 of 1
# Epoch [49/10000], Loss: 0.8027, Validation Loss: 0.6778, Accuracy: 60.18%
# Number batch 1 of 1
# Epoch [50/10000], Loss: 0.8027, Validation Loss: 0.6778, Accuracy: 60.18%
# Number batch 1 of 1
# Epoch [51/10000], Loss: 0.8027, Validation Loss: 0.6778, Accuracy: 60.18%
# Number batch 1 of 1
# Epoch [52/10000], Loss: 0.8027, Validation Loss: 0.6778, Accuracy: 60.18%
# Number batch 1 of 1
# Epoch [53/10000], Loss: 0.8028, Validation Loss: 0.6778, Accuracy: 60.18%
# Number batch 1 of 1
# Epoch [54/10000], Loss: 0.8028, Validation Loss: 0.6778, Accuracy: 59.73%
# Number batch 1 of 1
# Epoch [55/10000], Loss: 0.8028, Validation Loss: 0.6778, Accuracy: 59.73%
# Number batch 1 of 1
# Epoch [56/10000], Loss: 0.8028, Validation Loss: 0.6778, Accuracy: 59.73%
# Number batch 1 of 1
# Epoch [57/10000], Loss: 0.8028, Validation Loss: 0.6778, Accuracy: 59.73%
# Number batch 1 of 1
# Epoch [58/10000], Loss: 0.8028, Validation Loss: 0.6778, Accuracy: 59.73%
# Number batch 1 of 1
# Epoch [59/10000], Loss: 0.8028, Validation Loss: 0.6778, Accuracy: 59.73%
# Number batch 1 of 1
# Epoch [60/10000], Loss: 0.8028, Validation Loss: 0.6778, Accuracy: 59.73%
# Number batch 1 of 1
# Epoch [61/10000], Loss: 0.8028, Validation Loss: 0.6778, Accuracy: 59.73%
# Number batch 1 of 1
# Epoch [62/10000], Loss: 0.8028, Validation Loss: 0.6778, Accuracy: 59.73%
# Number batch 1 of 1
# Epoch [63/10000], Loss: 0.8028, Validation Loss: 0.6778, Accuracy: 59.73%
# Number batch 1 of 1
# Epoch [64/10000], Loss: 0.8028, Validation Loss: 0.6778, Accuracy: 59.73%
# Number batch 1 of 1
# Epoch [65/10000], Loss: 0.8028, Validation Loss: 0.6778, Accuracy: 59.73%
# Number batch 1 of 1
# Epoch [66/10000], Loss: 0.8028, Validation Loss: 0.6778, Accuracy: 59.73%
# Number batch 1 of 1
# Epoch [67/10000], Loss: 0.8028, Validation Loss: 0.6778, Accuracy: 59.73%
# Number batch 1 of 1
# Epoch [68/10000], Loss: 0.8028, Validation Loss: 0.6778, Accuracy: 59.73%
# Number batch 1 of 1
# Epoch [69/10000], Loss: 0.8028, Validation Loss: 0.6778, Accuracy: 59.73%
# Number batch 1 of 1
# Epoch [70/10000], Loss: 0.8028, Validation Loss: 0.6778, Accuracy: 59.73%
# Number batch 1 of 1
# Epoch [71/10000], Loss: 0.8028, Validation Loss: 0.6778, Accuracy: 59.73%
# Number batch 1 of 1
# Epoch [72/10000], Loss: 0.8028, Validation Loss: 0.6778, Accuracy: 59.73%
# Number batch 1 of 1
# Epoch [73/10000], Loss: 0.8028, Validation Loss: 0.6778, Accuracy: 59.73%
# Number batch 1 of 1
# Epoch [74/10000], Loss: 0.8028, Validation Loss: 0.6778, Accuracy: 59.73%
# Number batch 1 of 1
# Epoch [75/10000], Loss: 0.8028, Validation Loss: 0.6778, Accuracy: 59.73%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-8cfc4dec4903> in <cell line: 11>()
#      16     train_loader_epoch = DataLoader(train_dataset, batch_size=dynamic_batch_size, shuffle=True)
#      17     lenTrainLoader = len(train_loader_epoch)
# ---> 18     for batch in train_loader_epoch:
#      19         input_save, label_save = batch
#      20         if not torch.isnan(input_save.unsqueeze(1)).any():
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     628                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629                 self._reset()  # type: ignore[call-arg]
# --> 630             data = self._next_data()
#     631             self._num_yielded += 1
#     632             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     672     def _next_data(self):
#     673         index = self._next_index()  # may raise StopIteration
# --> 674         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675         if self._pin_memory:
#     676             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# <ipython-input-12-ee0337713ab3> in __getitem__(self, idx)
#      40
#      41         # Extract MFCC features
# ---> 42         mfcc = librosa.feature.mfcc(y=waveform, sr=sample_rate, n_mfcc=13, win_length = 400, n_fft=512, hop_length=30)
#      43         mfcc = 2 * (mfcc - mfcc.min()) / (mfcc.max() - mfcc.min()) - 1
#      44         #mfcc = (mfcc - mfcc.min()) / (mfcc.max() - mfcc.min())
#
# /usr/local/lib/python3.10/dist-packages/librosa/feature/spectral.py in mfcc(y, sr, S, n_mfcc, dct_type, norm, lifter, **kwargs)
#    1987     if S is None:
#    1988         # multichannel behavior may be different due to relative noise floor differences between channels
# -> 1989         S = power_to_db(melspectrogram(y=y, sr=sr, **kwargs))
#    1990
#    1991     M: np.ndarray = scipy.fftpack.dct(S, axis=-2, type=dct_type, norm=norm)[
#
# /usr/local/lib/python3.10/dist-packages/librosa/feature/spectral.py in melspectrogram(y, sr, S, n_fft, hop_length, win_length, window, center, pad_mode, power, **kwargs)
#    2141
#    2142     # Build a Mel filter
# -> 2143     mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
#    2144
#    2145     melspec: np.ndarray = np.einsum("...ft,mf->...mt", S, mel_basis, optimize=True)
#
# /usr/local/lib/python3.10/dist-packages/librosa/filters.py in mel(sr, n_fft, n_mels, fmin, fmax, htk, norm, dtype)
#     226
#     227     # 'Center freqs' of mel bands - uniformly spaced between limits
# --> 228     mel_f = mel_frequencies(n_mels + 2, fmin=fmin, fmax=fmax, htk=htk)
#     229
#     230     fdiff = np.diff(mel_f)
#
# /usr/local/lib/python3.10/dist-packages/librosa/core/convert.py in mel_frequencies(n_mels, fmin, fmax, htk)
#    1725     max_mel = hz_to_mel(fmax, htk=htk)
#    1726
# -> 1727     mels = np.linspace(min_mel, max_mel, n_mels)
#    1728
#    1729     hz: np.ndarray = mel_to_hz(mels, htk=htk)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in linspace(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     173         return y.astype(dtype, copy=False), step
#     174     else:
# --> 175         return y.astype(dtype, copy=False)
#     176
#     177
#
# KeyboardInterrupt:

# %%
model.load_state_dict(torch.load('/content/drive/My Drive/mfcc_ANN_highAcc_hap/CNN_PAPER.pth', map_location=torch.device('cpu')))
model.eval()  # Set the model to evaluation mode

test_loss = 0.0
correct = 0
total = 0
angry_detected = 0

with torch.no_grad():
    i = 0
    len_test = len(test_loader)
    for batch in test_loader:  # Assuming you have a DataLoader for your test set
        inputs, labels = batch
        inputs, labels = inputs.to(device), labels.to(device)
        if i % 100 == 0:
            print(str(i) + " / " + str(len_test))
        i += 1

        # Forward pass
        probs = model(inputs)
        loss = criterion(probs, labels.long())  # Use .long() for integer labels in CrossEntropyLoss
        test_loss += loss.item()

        # Accuracy calculation
        predicted = torch.argmax(probs, dim=1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        # Angry detection calculation
        angry_detected += ((predicted == 1) & (labels == 1)).sum().item()

average_test_loss = test_loss / len(test_loader)
accuracy = correct / total
angry_det_percentage = angry_detected / total

print(f'Test Loss: {average_test_loss:.4f}, Test Accuracy: {accuracy}, Angry Detection Percentage: {angry_det_percentage}')
# Out:
# 0 / 282
# 100 / 282
# 200 / 282
# Test Loss: 0.6670, Test Accuracy: 0.6205673758865248, Angry Detection Percentage: 0.3262411347517731

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the data from the CSV file
accuracy_per_epoch = np.loadtxt('/content/drive/My Drive/mfcc_ANN_highAcc_hap/accuracy.csv', delimiter=',')
# Load the data from the CSV files
validation_loss_per_epoch = np.loadtxt('/content/drive/My Drive/mfcc_ANN_highAcc_hap/validation_loss.csv', delimiter=',')
trainingloss_per_epoch = np.loadtxt('/content/drive/My Drive/mfcc_ANN_highAcc_hap/training_loss.csv', delimiter=',')

# Plot for Validation Loss
plt.figure(figsize=(8, 4))
plt.plot(validation_loss_per_epoch, label='Validation Loss', color='red', linestyle='--')
plt.xlabel('Epoch')
plt.ylabel('Validation Loss')
plt.title('Validation Loss per Epoch')
plt.legend()
plt.show()

# %%
# Plot for Accuracy
plt.figure(figsize=(8, 4))
plt.plot(accuracy_per_epoch, label='Accuracy', color='blue', linestyle='-')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy per Epoch')
plt.legend()
plt.show()

# %%
# Plot the data using the index as the x-axis values
plt.plot(trainingloss_per_epoch)
plt.xlabel('Epoch')
plt.ylabel('Trainingsloss')
plt.title('Trainingsloss per Epoch')
plt.show()
