# %% [markdown]
# <a href="https://colab.research.google.com/github/TobiasWinfriedWeber/DSAP_SER/blob/main/CNN_repeated_sad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import basic libraries
import matplotlib.pyplot as plt
import numpy as np
# Mount to drive
from google.colab import drive
drive.flush_and_unmount()
drive.mount("/content/drive")
# Import torch
import torch
import torch.nn as nn
import torch.optim as optim
import os
from scipy.io import wavfile
import shutil
import csv
path = "/content/drive" # /content is pretty much the root. you can choose other path in your colab workspace
os.chdir(path)
# Out:
# Drive not mounted, so nothing to flush and unmount.
# Mounted at /content/drive

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("We are using the following device for learning:",device)
# Out:
# We are using the following device for learning: cpu

# %%
import torch.nn as nn
import torch.optim as optim
import torch
import torchaudio
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import Compose
import os
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import math

class SimpleCNN(nn.Module):
    def __init__(self, hidden_neurons, filter_len, filter_shift, maxPoolSize, maxPoolShift):
        super(SimpleCNN, self).__init__()
        self.outCONVsize = math.floor((80e3 - filter_len) / filter_shift + 1)
        self.outMAXPOOLsize = math.floor((self.outCONVsize - maxPoolSize) / maxPoolShift + 1)
        print("Input size fc: " + str(self.outMAXPOOLsize))

        # Convolutional layer
        self.conv1d = nn.Conv1d(in_channels=1, out_channels=1, kernel_size=filter_len, stride=filter_shift)
        # Max-pooling layer
        self.maxpool = nn.MaxPool1d(kernel_size=maxPoolSize, stride=maxPoolShift)
        self.dropout = nn.Dropout(p=0.2)
        # Fully connected (linear) layer
        self.fc = nn.Linear(self.outMAXPOOLsize, hidden_neurons)
        # ReLU activation function for hidden layer
        self.relu = nn.ReLU()
        # Output layer
        self.output_layer = nn.Linear(hidden_neurons, 2)  # Two output classes

    def forward(self, x):
        # Convolutional layer
        x = self.conv1d(x)
        x = self.relu(x)
        # Max-pooling layer
        x = self.maxpool(x)

        # Flatten for fully connected layer
        x = x.view(x.size(0), -1)
        # Fully connected layer
        x = self.fc(x)
        x = self.relu(x)
        # Output layer
        x = self.output_layer(x)
        x = nn.functional.softmax(x, dim=1)  # Apply softmax activation

        return x

# %%
# Install required packages
import torch
import torchaudio
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import Compose
import os
import pandas as pd
from sklearn.model_selection import train_test_split

# Load your CSV file
#csv_path = "/content/drive/My Drive/DSAP/BigProject/DATA/ANGRY_CLASSIFICATION/labels.csv"
csv_path = "/content/drive/My Drive/DSAP/BigProject/DATA/SAD_CLASSIFICATION_SAME_REP/labels_sameprobability.csv"
df = pd.read_csv(csv_path)

# Split the data into training, validation, and test sets
# Shuffle the dataframe
df = df.sample(frac=1, random_state=42)
#df = df.head(4000)
temp_df, test_df = train_test_split(df, test_size=0.2, random_state=42)
train_df, val_df = train_test_split(temp_df, test_size=0.2, random_state=42)

# Define a custom dataset for loading audio files
class AudioDataset(Dataset):
    def __init__(self, dataframe, root_dir, transform=None):
        self.dataframe = dataframe
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        file_name = os.path.join(self.root_dir, self.dataframe.iloc[idx, 0])
        waveform, sample_rate = torchaudio.load(file_name)
        label = torch.tensor(self.dataframe.iloc[idx, 1], dtype=torch.float32)  # Assuming labels are in the second column

        # Normalize the waveform to be between 0 and 1
        #waveform = (waveform - waveform.min()) / (waveform.max() - waveform.min())
        waveform = 2 * (waveform - waveform.min()) / (waveform.max() - waveform.min()) - 1


        if self.transform:
            waveform = self.transform(waveform)

        return waveform, label

# Set the path to your directory containing audio files
#audio_dir = "/content/drive/My Drive/DSAP/BigProject/DATA/CremaD/AudioWAV_samelength"
audio_dir = "/content/drive/My Drive/DSAP/BigProject/DATA/CremaD/SAD_SAMEPROP_REP"
# Create instances of the custom dataset for training, validation, and test
train_dataset = AudioDataset(dataframe=train_df, root_dir=audio_dir)
val_dataset = AudioDataset(dataframe=val_df, root_dir=audio_dir)
test_dataset = AudioDataset(dataframe=test_df, root_dir=audio_dir)

# Define data loaders
#train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
## Settings
sampling_rate = 16e3 #was tested before
#Calculate the number of samples per window for a 25ms window size
kernelCON_len = int(0.025 * sampling_rate)
# move window of one fourth of kernel size
shiftCON_size = int(0.25 * kernelCON_len)
print(f"Kernel size is : {kernelCON_len} Samples")

hidden_neurons = 8
maxPoolLen = 4
maxPoolStride = 4

num_epochs = 10000
# Out:
# Kernel size is : 400 Samples

# %%
# Create an instance of the model, define loss
model = SimpleCNN(hidden_neurons=hidden_neurons, filter_len=kernelCON_len, filter_shift = shiftCON_size, maxPoolSize=maxPoolLen, maxPoolShift=maxPoolStride)
#optimizer = optim.Adam(model.parameters(), lr=0.001)
optimizer = optim.SGD(model.parameters(), lr=0.9, momentum=0.9) # in paper: sgd 0.9, 0.9
lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=15, gamma=0.2) # gamma = 0.2
model.to( device )
criterion = nn.CrossEntropyLoss()
#criterion = nn.MSELoss()

# Early stopping parameters
patience = 50  # Number of epochs with no improvement after which training will be stopped
best_val_loss = float('inf')
counter_no_improve = 0

# Save parameters
trainingloss_per_epoch = []
validationloss_per_epoch = []
accuracy_per_epoch = []

model_parameters = filter(lambda p: p.requires_grad, model.parameters())
params = sum([np.prod(p.size()) for p in model_parameters])
print(params)
# Out:
# Input size fc: 199
# 2019

# %%
# Training loop
#max_grad_norm = 100000000.0
dynamic_batch_size = 561
from torch.nn.utils import clip_grad_norm_
import torch
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
import os


for epoch in range(num_epochs):
    model.train()
    i=0

      # Set your initial batch size
    train_loader_epoch = DataLoader(train_dataset, batch_size=dynamic_batch_size, shuffle=True)
    lenTrainLoader = len(train_loader_epoch)
    for batch in train_loader_epoch:
        input_save, label_save = batch
        if not torch.isnan(input_save.unsqueeze(1)).any():
          inputs, labels = batch
          inputs, labels = inputs.to(device), labels.to(device)

          # Zero the gradients
          optimizer.zero_grad()

          # Forward pass
          outputs = model(inputs)
          #outputs = torch.sigmoid(outputs)
          if i%40 == 0 or i==0:
            #print(labels.unsqueeze(1))
            #print("#######################################################")
            #print(outputs)
            #print(labels)
            #print("#######################################################")
            print("Number batch " + str(i) + " of " + str(lenTrainLoader))
          #if math.isnan(outputs):
          #  print(input_save)
          i+=1
          # Calculate the loss
          loss = criterion(outputs, labels.long())



          # Backward pass
          loss.backward()
          #clip_grad_norm_(model.parameters(), max_grad_norm)

          # Update weights
          optimizer.step()

          i += 1

    # Validation loop
    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for batch in val_loader:
            inputs, labels = batch
            inputs, labels = inputs.to(device), labels.to(device)

            # Forward pass
            outputs = model(inputs)
            #outputs = torch.sigmoid(outputs)

            # Calculate the loss
            loss = criterion(outputs, labels.long())
            val_loss += loss.item()

            # Accuracy calculation
            predicted = torch.argmax(outputs, dim=1)
            #predicted = torch.round(outputs)
            total += labels.size(0)
            correct += (predicted == labels.unsqueeze(1)).sum().item()

    average_val_loss = val_loss / len(val_loader)
    accuracy = correct / total
    lr_scheduler.step()
    print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}, Validation Loss: {average_val_loss:.4f}, Accuracy: {accuracy * 100:.2f}%')
    # Append values to the existing lists
    trainingloss_per_epoch.append(loss.cpu().item())
    validationloss_per_epoch.append(average_val_loss)
    accuracy_per_epoch.append(accuracy)
    np.savetxt('/content/drive/My Drive/cnn_softmax_rep_sad/training_loss.csv', trainingloss_per_epoch, delimiter=',')
    np.savetxt('/content/drive/My Drive/cnn_softmax_rep_sad/validation_loss.csv', validationloss_per_epoch, delimiter=',')
    np.savetxt('/content/drive/My Drive/cnn_softmax_rep_sad/accuracy.csv', accuracy_per_epoch, delimiter=',')
    # Learning rate scheduling
    lr_scheduler.step()


    # Early stopping
    if average_val_loss < best_val_loss:
        torch.save(model.state_dict(), '/content/drive/My Drive/cnn_softmax_rep_sad/CNN_PAPER.pth')

        #if dynamic_batch_size*1.5<598:
        #  dynamic_batch_size = int(dynamic_batch_size*1.5)
        best_val_loss = average_val_loss
        counter_no_improve = 0
    else:
        counter_no_improve += 1

    #if counter_no_improve >= patience:
    #    print(f'Early stopping! No improvement for {patience} consecutive epochs.')
    #    break
print('Training finished.')
# Out:
# Number batch 0 of 1
# Epoch [1/10000], Loss: 0.6674, Validation Loss: 0.6959, Accuracy: 45.39%
# Number batch 0 of 1
# Epoch [2/10000], Loss: 0.6652, Validation Loss: 0.6953, Accuracy: 45.39%
# Number batch 0 of 1
# Epoch [3/10000], Loss: 0.6587, Validation Loss: 0.6940, Accuracy: 45.39%
# Number batch 0 of 1
# Epoch [4/10000], Loss: 0.6491, Validation Loss: 0.6913, Accuracy: 45.39%
# Number batch 0 of 1
# Epoch [5/10000], Loss: 0.6414, Validation Loss: 0.6846, Accuracy: 45.39%
# Number batch 0 of 1
# Epoch [6/10000], Loss: 0.6767, Validation Loss: 0.6682, Accuracy: 46.81%
# Number batch 0 of 1
# Epoch [7/10000], Loss: 0.7080, Validation Loss: 0.6429, Accuracy: 63.83%
# Number batch 0 of 1
# Epoch [8/10000], Loss: 0.8144, Validation Loss: 0.6257, Accuracy: 72.34%
# Number batch 0 of 1
# Epoch [9/10000], Loss: 0.8309, Validation Loss: 0.6220, Accuracy: 71.63%
# Number batch 0 of 1
# Epoch [10/10000], Loss: 0.8461, Validation Loss: 0.6170, Accuracy: 73.05%
# Number batch 0 of 1
# Epoch [11/10000], Loss: 0.8605, Validation Loss: 0.6113, Accuracy: 70.92%
# Number batch 0 of 1
# Epoch [12/10000], Loss: 0.8742, Validation Loss: 0.6057, Accuracy: 70.92%
# Number batch 0 of 1
# Epoch [13/10000], Loss: 0.8909, Validation Loss: 0.6000, Accuracy: 72.34%
# Number batch 0 of 1
# Epoch [14/10000], Loss: 0.9159, Validation Loss: 0.5941, Accuracy: 73.05%
# Number batch 0 of 1
# Epoch [15/10000], Loss: 0.9462, Validation Loss: 0.5887, Accuracy: 74.47%
# Number batch 0 of 1
# Epoch [16/10000], Loss: 0.9523, Validation Loss: 0.5878, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [17/10000], Loss: 0.9583, Validation Loss: 0.5869, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [18/10000], Loss: 0.9641, Validation Loss: 0.5860, Accuracy: 73.05%
# Number batch 0 of 1
# Epoch [19/10000], Loss: 0.9697, Validation Loss: 0.5852, Accuracy: 73.05%
# Number batch 0 of 1
# Epoch [20/10000], Loss: 0.9749, Validation Loss: 0.5844, Accuracy: 73.05%
# Number batch 0 of 1
# Epoch [21/10000], Loss: 0.9797, Validation Loss: 0.5836, Accuracy: 73.05%
# Number batch 0 of 1
# Epoch [22/10000], Loss: 0.9841, Validation Loss: 0.5827, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [23/10000], Loss: 0.9878, Validation Loss: 0.5819, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [24/10000], Loss: 0.9884, Validation Loss: 0.5817, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [25/10000], Loss: 0.9890, Validation Loss: 0.5815, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [26/10000], Loss: 0.9896, Validation Loss: 0.5813, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [27/10000], Loss: 0.9901, Validation Loss: 0.5811, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [28/10000], Loss: 0.9906, Validation Loss: 0.5808, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [29/10000], Loss: 0.9910, Validation Loss: 0.5806, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [30/10000], Loss: 0.9914, Validation Loss: 0.5804, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [31/10000], Loss: 0.9915, Validation Loss: 0.5803, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [32/10000], Loss: 0.9916, Validation Loss: 0.5803, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [33/10000], Loss: 0.9917, Validation Loss: 0.5802, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [34/10000], Loss: 0.9917, Validation Loss: 0.5802, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [35/10000], Loss: 0.9918, Validation Loss: 0.5801, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [36/10000], Loss: 0.9919, Validation Loss: 0.5801, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [37/10000], Loss: 0.9920, Validation Loss: 0.5800, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [38/10000], Loss: 0.9921, Validation Loss: 0.5800, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [39/10000], Loss: 0.9921, Validation Loss: 0.5800, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [40/10000], Loss: 0.9921, Validation Loss: 0.5800, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [41/10000], Loss: 0.9921, Validation Loss: 0.5800, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [42/10000], Loss: 0.9921, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [43/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [44/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [45/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [46/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [47/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [48/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [49/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [50/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [51/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [52/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [53/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [54/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [55/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [56/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [57/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [58/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [59/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [60/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [61/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [62/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [63/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [64/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [65/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [66/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [67/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [68/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [69/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [70/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [71/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [72/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [73/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [74/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [75/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [76/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [77/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [78/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [79/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [80/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [81/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [82/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [83/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [84/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [85/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [86/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [87/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [88/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [89/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [90/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [91/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [92/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [93/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [94/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [95/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [96/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [97/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [98/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [99/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [100/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [101/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [102/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [103/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [104/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [105/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [106/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [107/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [108/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [109/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [110/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [111/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [112/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [113/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [114/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [115/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [116/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [117/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [118/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [119/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [120/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [121/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [122/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [123/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [124/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [125/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# Number batch 0 of 1
# Epoch [126/10000], Loss: 0.9922, Validation Loss: 0.5799, Accuracy: 73.76%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-15f5eff377fa> in <cell line: 11>()
#      16     train_loader_epoch = DataLoader(train_dataset, batch_size=dynamic_batch_size, shuffle=True)
#      17     lenTrainLoader = len(train_loader_epoch)
# ---> 18     for batch in train_loader_epoch:
#      19         input_save, label_save = batch
#      20         if not torch.isnan(input_save.unsqueeze(1)).any():
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     628                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629                 self._reset()  # type: ignore[call-arg]
# --> 630             data = self._next_data()
#     631             self._num_yielded += 1
#     632             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     672     def _next_data(self):
#     673         index = self._next_index()  # may raise StopIteration
# --> 674         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675         if self._pin_memory:
#     676             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# <ipython-input-10-1b2b81fa30d5> in __getitem__(self, idx)
#      32     def __getitem__(self, idx):
#      33         file_name = os.path.join(self.root_dir, self.dataframe.iloc[idx, 0])
# ---> 34         waveform, sample_rate = torchaudio.load(file_name)
#      35         label = torch.tensor(self.dataframe.iloc[idx, 1], dtype=torch.float32)  # Assuming labels are in the second column
#      36
#
# /usr/local/lib/python3.10/dist-packages/torchaudio/_backend/utils.py in load(uri, frame_offset, num_frames, normalize, channels_first, format, buffer_size, backend)
#     201         """
#     202         backend = dispatcher(uri, format, backend)
# --> 203         return backend.load(uri, frame_offset, num_frames, normalize, channels_first, format, buffer_size)
#     204
#     205     return load
#
# /usr/local/lib/python3.10/dist-packages/torchaudio/_backend/ffmpeg.py in load(uri, frame_offset, num_frames, normalize, channels_first, format, buffer_size)
#     332             )
#     333         else:
# --> 334             return load_audio(os.path.normpath(uri), frame_offset, num_frames, normalize, channels_first, format)
#     335
#     336     @staticmethod
#
# /usr/local/lib/python3.10/dist-packages/torchaudio/_backend/ffmpeg.py in load_audio(src, frame_offset, num_frames, convert, channels_first, format)
#      98 ) -> Tuple[torch.Tensor, int]:
#      99     filter = _get_load_filter(frame_offset, num_frames, convert)
# --> 100     return torch.ops.torchaudio.compat_load(src, format, filter, channels_first)
#     101
#     102
#
# /usr/local/lib/python3.10/dist-packages/torch/_ops.py in __call__(self, *args, **kwargs)
#     690         # We save the function ptr as the `op` attribute on
#     691         # OpOverloadPacket to access it here.
# --> 692         return self._op(*args, **kwargs or {})
#     693
#     694     # TODO: use this to make a __dir__
#
# KeyboardInterrupt:

# %%
model.load_state_dict(torch.load('/content/drive/My Drive/cnn_softmax_rep_sad/CNN_PAPER.pth')) #, map_location=torch.device('cpu')))
model.eval()  # Set the model to evaluation mode

test_loss = 0.0
correct = 0
total = 0
angry_detected = 0

with torch.no_grad():
    i = 0
    len_test = len(test_loader)
    for batch in test_loader:  # Assuming you have a DataLoader for your test set
        inputs, labels = batch
        inputs, labels = inputs.to(device), labels.to(device)
        if i % 100 == 0:
            print(str(i) + " / " + str(len_test))
        i += 1

        # Forward pass
        probs = model(inputs)
        loss = criterion(probs, labels.long())  # Use .long() for integer labels in CrossEntropyLoss
        test_loss += loss.item()

        # Accuracy calculation
        predicted = torch.argmax(probs, dim=1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        # Angry detection calculation
        angry_detected += ((predicted == 1) & (labels == 1)).sum().item()

average_test_loss = test_loss / len(test_loader)
accuracy = correct / total
angry_det_percentage = angry_detected / total

print(f'Test Loss: {average_test_loss:.4f}, Test Accuracy: {accuracy}, Angry Detection Percentage: {angry_det_percentage}')
# Out:
# 0 / 176
# 100 / 176
# Test Loss: 0.5844, Test Accuracy: 0.7386363636363636, Angry Detection Percentage: 0.4034090909090909

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the data from the CSV file
accuracy_per_epoch = np.loadtxt('/content/drive/My Drive/cnn_softmax_rep_sad/accuracy.csv', delimiter=',')
# Load the data from the CSV files
validation_loss_per_epoch = np.loadtxt('/content/drive/My Drive/cnn_softmax_rep_sad/validation_loss.csv', delimiter=',')
trainingloss_per_epoch = np.loadtxt('/content/drive/My Drive/cnn_softmax_rep_sad/training_loss.csv', delimiter=',')

# Plot for Validation Loss
plt.figure(figsize=(8, 4))
plt.plot(validation_loss_per_epoch, label='Validation Loss', color='red', linestyle='--')
plt.xlabel('Epoch')
plt.ylabel('Validation Loss')
plt.title('Validation Loss per Epoch')
plt.legend()
plt.show()

# %%
# Plot for Accuracy
plt.figure(figsize=(8, 4))
plt.plot(accuracy_per_epoch, label='Accuracy', color='blue', linestyle='-')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy per Epoch')
plt.legend()
plt.show()

# %%
# Plot the data using the index as the x-axis values
plt.plot(trainingloss_per_epoch)
plt.xlabel('Epoch')
plt.ylabel('Trainingsloss')
plt.title('Trainingsloss per Epoch')
plt.show()
